# %%
import pandas as pd
import numpy as np

# %%
call119 = pd.read_csv(r"C:\Users\user\OneDrive\바탕 화면\22-23 컨퍼런스\merged3_population.csv", encoding='utf-8')

# %%
call119.head()
# Out:
#          tm address_city address_gu sub_address cat sub_cat  stn_cat  \
# 0  20200501        부산광역시        강서구        대저2동  구급    교통사고      904
# 1  20200501        부산광역시        강서구         천성동  구조    교통사고      921
# 2  20200501        부산광역시        금정구         금사동  구급      부상      940
# 3  20200501        부산광역시        금정구         금성동  기타    업무운행      941
# 4  20200501        부산광역시        금정구         남산동  구급      부상      939
#
#    call_count_cat  year  month  ...  pop_여_10~19세  pop_여_20~29세  pop_여_30~39세  \
# 0               1  2020      5  ...         5,289         5,521        12,909
# 1               1  2020      5  ...         5,289         5,521        12,909
# 2               1  2020      5  ...         8,998        15,561        12,722
# 3               1  2020      5  ...         8,998        15,561        12,722
# 4               1  2020      5  ...         8,998        15,561        12,722
#
#    pop_여_40~49세  pop_여_50~59세  pop_여_60~69세  pop_여_70~79세  pop_여_80~89세  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 git --version
#
# NameError: name 'git' is not defined
